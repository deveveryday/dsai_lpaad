# %% [markdown]
# 1 Exercício 1 – Primeiro Programa
# Desenvolva um programa em Python que:
# 1. Exiba a mensagem:
# "Bem-vindo à disciplina de Linguagens de Programação Aplicadas à
# Análise de Dados!"
# 2. Exiba seu nome.
# 3. Exiba sua cidade.
# 4. Exiba o nome do curso

# %%
message = "Bem-vindo à disciplina de Linguagens de Programação Aplicadas à Análise de Dados!"
name = ""
city = ""
course = ""

print(message)
print(name, city, course)

# %% [markdown]
# 2 Exercício 2 - Variáveis
# Crie variáveis para armazenar as seguintes informações:
#
# • Nome
# • Idade
# • Cidade
#
# Em seguida, exiba todas as informações utilizando o comando print().

# %%
name = ""
age = 0
city = ""

print(name, age, city)

# %% [markdown]
# 3 Exercício 3 – Recebendo Informações do Usuário
# Desenvolva um programa em Python que:
#
# 1. Solicite ao usuário:
# • Nome;
#
# • Curso,
#
# • Semestre,
#
# • Quantidade de disciplinas.
#
#
# 2. Exiba uma mensagem personalizada utilizando uma f-string, contendo todas as
# informações cadastradas.

# %%
name = input("Type your name ")
semester = input("Type which semester your are in ")
discpline_amount = input("Type how many discplines you got ")

message = f"The name: {name}\n Semester: {semester}\n {discpline_amount} disciplines"
# Out:
# Type your name a
# Type which semester your are in a
# Type how many discplines you got a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_820/801514532.py in <cell line: 0>()
#       3 discpline_amount = input("Type how many discplines you got ")
#       4
# ----> 5 message = f"The name: {name}\n Semester: {semester}\n {discipline_amount} disciplines"
#
# NameError: name 'discipline_amount' is not defined

# %% [markdown]
# 4 Exercício 4 – Descobrindo o Tipo das Variáveis
# Desenvolva um programa que:
# 1. Solicite ao usuário:
#
# • Nome;
#
# • Idade;
#
# • Salário;
#
# • Cidade.

# %%
 name = input("Type your name: ")
 age = int(input("Type your age: "))
 salary = float(input("How many money you make per month? "))
 city = input("Type the name of the city that you live: ")

 print(name, age, salary, city)

# %% [markdown]
# 5 Exercício 5 – Convertendo Tipos
# Desenvolva um programa que:
#
# 1. Solicite ao usuário (usando apenas input()):
#
# • Idade;
#
# • Altura;
#
# • Salário.
#
#
# 2. Converta:
#
# • Idade para int();
#
# • Altura para float();
#
# • Salário para float().
#
#
# 3. Utilize novamente a função type() para exibir o tipo das variáveis após a conversão

# %%
age_input = input("Type the age: ")
height_input = input("Type your height: ")
income_input = input("Type your income: $")

age = int(age_input)
height = float(height_input)
income = float(income_input)

print(type(age), type(height), type(income))
# Out:
# Type the age: 1
# Type your height: 1
# Type your income: $1

# %% [markdown]
# 6 Exercício 6 – Operadores Aritméticos
# Desenvolva um programa que:
#
# 1. Solicite dois valores numéricos.
#
# 2. Calcule:
#
# • Soma;
#
# • Subtração;
#
# • Multiplicação;
#
# • Divisão;
#
# • Divisão inteira;
#
# • Resto da divisão;
#
# • Potência.
#
#
# 3. Exiba todos os resultados

# %%
def my_sum(value_one, value_two):
	return value_one + value_two


def my_subtract(value_one, value_two):
	return value_one - value_two


def my_multiply(value_one, value_two):
	return value_one * value_two


def my_divide(value_one, value_two):
	return value_one * value_two


def my_divide_without_rest(value_one, value_two):
	return value_one // value_two


def my_rest(value_one, value_two):
	return value_one % value_two


def my_potential(value_one, value_two):
	return value_one ** value_two

value_one = float(input("Type value one "))
value_two = float(input("Type the second value "))

print(my_sum(value_one, value_two))
print(my_subtract(value_one, value_two))
print(my_multiply(value_one, value_two))
print(my_divide(value_one, value_two))
print(my_divide_without_rest(value_one, value_two))
print(my_rest(value_one, value_two))
print(my_potential(value_one, value_two))
# Out:
# Type value one1
# Type the second value2
# 3.0
# -1.0
# 2.0
# 2.0
# 0.0
# 1.0
# 1.0

# %% [markdown]
# 7 Exercício 7 – Formatação com f-strings
# Uma empresa concedeu um aumento salarial de 12% para seus colaboradores.
# Desenvolva um programa que:
#
# 1. Solicite:
#
# • Nome do colaborador;
#
# • Salário atual.
#
#
# 2. Calcule o novo salário após o aumento.
#
# 3. Exiba uma mensagem semelhante a:
# O colaborador João possuía salário de R$ 3.250,00 e passou a receber R$ 3.640,00, após o aumento de 12%.
#
# Utilize f-string e apresente os valores com duas casas decimais.

# %%
name = input("Type the employee name ")
salary = float(input("Type your salary "))
new_salary = salary * 1.12

message = f"The colaborator \"{name}\" had the ${salary:.2f} income, now he has ${new_salary:.2f}"

print(message)
# Out:
# Type the employee name a
# Type your salary 1000
# The colaborator (a) had the $1000.000 income, now he has $1120.000

# %% [markdown]
# 8 Exercício 8 – Ordem de Precedência
# 1. Escreva em Python as seguintes expressões matemáticas:
#
# (a) 5 × 2
#
# 3 + 1
#
#
# (b) 5
# 2
# 5
#
#
# (c) (33 − 3) × 4 − 2
#
#
# 2. Digite no Python a expressão abaixo:
#
# 10%3 ∗ 102 + 1 − 10 ∗ 4/2
#
# 3. Resolva a mesma expressão manualmente e compare com os resultados obtidos em
# Python

# %%
a = 5 * (2**3) + 1
b = (5**2) / 5
c = ((3**3) - 3) * (4 - 2)

expression = 10%3 * 102 + 1 - 10 * 4/2

print(a, b, c, expression)

# %% [markdown]
# 9 Exercício 9 – Conversão de Temperatura
# Uma empresa de monitoramento ambiental registra temperaturas em graus Celsius, porém
# um cliente internacional necessita que os valores sejam apresentados em Fahrenheit.
#
# A conversão é dada por:
# F =
# 9
# 5
# C + 32
#
# Desenvolva um programa que:
#
# 1. Solicite ao usuário a temperatura em graus Celsius.
#
# 2. Calcule a temperatura equivalente em Fahrenheit.
#
# 3. Exiba uma mensagem utilizando f-string, apresentando as duas temperaturas com
# duas casas decimais.

# %%
temperature = float(input("Type the temperature: "))
fahrenheit_temperature = (9/5 * temperature) + 32

print(f"{temperature:.2f}C\n{fahrenheit_temperature:.2f}F")

# %% [markdown]
# 10 Exercício 10 – Índice de Massa Corporal
# Uma clínica deseja automatizar o cálculo do Índice de Massa Corporal (IMC).
# A fórmula é dada por:
# IMC =
# peso
# altura2
# Desenvolva um programa que:
# 6
# 1. Solicite ao usuário:
# • Nome;
# • Peso (kg);
# • Altura (m).
# 2. Calcule o IMC.
# 3. Exiba uma mensagem utilizando f-string, contendo o nome do paciente e o IMC
# calculado, apresentando o resultado com duas casas decimais.

# %%
name = input("Type your name ")
weight = float(input("Type your weight "))
height = float(input("Type your height "))

imc = weight/(height**2)

message = f"The name is {name} and the IMC number is {imc:.2f}"

# %% [markdown]
# 11 Exercício 11 – Velocidade Média
# Durante um teste automotivo foram registrados a distância percorrida e o tempo gasto na
# viagem.
# A velocidade média é dada por:
# Vm =
# d
# t
# Desenvolva um programa que:
# 1. Solicite a distância percorrida (km).
# 2. Solicite o tempo gasto (h).
# 3. Calcule a velocidade média.
# 4. Exiba o resultado utilizando uma f-string, com duas casas decimais.

# %%
distance = float(input("How many kilometers did you drive "))
time_spent = float(input("How many hours did you spend "))

mean_speed = distance / time_spent

print(f"The mean speed was {mean_speed:.2f}")

# %% [markdown]
# 12 Exercício 12 – Consumo Médio de Combustível
# Uma empresa de logística registrou a distância percorrida por um veículo e a quantidade
# de combustível consumida durante uma entrega.
# O consumo médio é dado por:
# C =
# d
# L
# Desenvolva um programa que:
# 1. Solicite a distância percorrida (km).
# 2. Solicite a quantidade de combustível consumido (L).
# 3. Calcule o consumo médio em km/L.
# 4. Exiba o resultado utilizando uma f-string, apresentando o valor com duas casas
# decimais.

# %%
distance = float(input("How many kilometers did you drive "))
gasoline = float(input("How many liters did you spend "))

consume = distance / gasoline

print(f"The fuel consume was {consume:.2f}")

# %% [markdown]
# 13 Exercício 13 – Utilizando a função sum()
# Uma empresa registrou a quantidade de clientes atendidos durante quatro dias consecutivos.
# Desenvolva um programa que:
# 1. Solicite a quantidade de clientes atendidos em cada dia.
# 2. Utilize a função sum() para calcular o total de clientes atendidos.
# 3. Calcule a média diária de atendimentos.
# 4. Exiba os resultados utilizando f-strings.

# %%
clients_day_one = int(input("How many clients you had today"))
clients_day_two = int(input("Now, how many clients you had today"))
clients_day_three = int(input("And today, how many clients"))
clients_day_four = int(input("How many clients in the last day"))

amount = sum(clients_day_one, clients_day_two, clients_day_three, clients_day_four)
mean = amount / 4

message = f"You had {amount} clients and the mean is {mean}"

print(message)

# %% [markdown]
# 14 Exercício 14 – Utilizando a função max()
# Uma empresa registrou o faturamento de cinco vendedores.
# Desenvolva um programa que:
# 1. Solicite o faturamento de cada vendedor.
# 2. Utilize a função max() para identificar o maior faturamento.
# 3. Exiba uma mensagem informando o maior valor encontrado.
# 4. Exiba também o faturamento médio.

# %%
clients_one = float(input("What is the amount made by seller one "))
clients_two = float(input("What is the amount made by seller two "))
clients_three = float(input("What is the amount made by seller three "))
clients_four = float(input("What is the amount made by seller four "))
clients_five = float(input("What is the amount made by seller five "))


amount = [clients_day_one, clients_day_two, clients_day_three, clients_day_four]
better_seller = max(amount)
mean = sum(clients_day_one, clients_day_two, clients_day_three, clients_day_four) / 5

print(f"Better seller is {better_seller} and the mean is {mean}")

# %% [markdown]
# 15 Exercício 15 – Utilizando as funções sum(), max()
# e min()
# Uma empresa registrou a quantidade de peças produzidas durante cinco dias consecutivos.
# Desenvolva um programa que:
# 1. Solicite a produção diária.
# 2. Utilize:
# • sum() para calcular a produção total;
# • max() para identificar a maior produção diária;
# • min() para identificar a menor produção diária.
# 3. Calcule a produção média da semana.
# 4. Exiba todos os resultados utilizando f-strings.

# %%
day_one = int(input("What is the production today "))
day_two = int(input("What is the production today "))
day_three = int(input("What is the production today "))
day_four = int(input("What is the production today "))
day_five = int(input("What is the production today "))

amount_list = [day_one, day_two, day_three, day_four, day_five]

total = sum(amount_list)
better = max(amount_list)
worse = min(amount_list)
mean = total / 5

print(f"Total {total}", f"Better production {better}", f"Worse production {worse}", f"Mean production {mean}")

# %% [markdown]
# 16 Exercício 16 – Controle de Estoque
# Uma empresa possui cinco depósitos e deseja conhecer a distribuição dos produtos armazenados.
# Desenvolva um programa que:
# 1. Solicite a quantidade de produtos existente em cada depósito.
# 2. Calcule o estoque total utilizando sum().
# 3. Calcule o estoque médio.
# 4. Determine o maior estoque utilizando max().
# 5. Determine o menor estoque utilizando min().
# 6. Exiba um relatório contendo todos os resultados.

# %%
stock_one = int(input("What is the amount in stock one "))
stock_two = int(input("What is the amount in stock two "))
stock_three = int(input("What is the amount in stock three "))
stock_four = int(input("What is the amount in stock four "))
stock_five = int(input("What is the amount in stock five "))

amount_list = [stock_one, stock_two, stock_three, stock_four, stock_five]

total = sum(amount_list)
better = max(amount_list)
worse = min(amount_list)
mean = total / 5

print(f"Total {total}", f"Greater value {better}", f"Smaller value {worse}", f"Mean production {mean}")
# Out:
# What is the amount in stock one 1
# What is the amount in stock two 2
# What is the amount in stock three 3
# What is the amount in stock four 4
# What is the amount in stock five 6
# Total 16 Greater value 6 Smaller value 1 Mean production 3.2

# %% [markdown]
# 17 Exercício 17 – Receita de Vendas
# Uma empresa comercializou cinco produtos durante um determinado período.
# Desenvolva um programa que:
# 1. Solicite o faturamento de cada produto.
# 2. Calcule o faturamento total utilizando sum().
# 3. Calcule o faturamento médio.
# 4. Determine o maior faturamento utilizando max().
# 5. Determine o menor faturamento utilizando min().
# 6. Calcule a diferença entre o maior e o menor faturamento.
# 7. Exiba um relatório contendo todas as informações.

# %%
product_one = float(input("What is the price of product one "))
product_two = float(input("What is the price of product two "))
product_three = float(input("What is the price of product three "))
product_four = float(input("What is the price of product four "))
product_five = float(input("What is the price of product five "))

amount_list = [stock_one, stock_two, stock_three, stock_four, stock_five]

total = sum(amount_list)
better = max(amount_list)
worse = min(amount_list)
difference = better - worse

print(f"Total {total}", f"Greater value {better}", f"Smaller value {worse}", f"The difference {difference}")
# Out:
# What is the price of product one 3
# What is the price of product two 3
# What is the price of product three 4
# What is the price of product four 5
# What is the price of product five 6
# Total 16 Greater value 6 Smaller value 1 The difference 5

# %% [markdown]
# 18 Desafio: Índice de Eficiência Operacional
# Uma indústria deseja desenvolver um indicador para avaliar o desempenho diário de uma
# linha de produção. O Índice de Eficiência Operacional (IEO) é definido por:
# IEO =
#
# P − R
# H
#
# ×
# Q
# 100
# ,
# onde
# • P = Produção diária
# • R = Quantidade de peças rejeitadas
# • H = Horas trabalhadas
# • Q = Percentual de peças aprovadas
# Sabendo que
# T R =
# R
# P
# × 100
# e
# P A = 100 − T R
# desenvolva um programa que:
# 1. Solicite a produção diária.
# 2. Solicite a quantidade de peças rejeitadas.
# 3. Solicite o número de horas trabalhadas.
# 4. Calcule a Taxa de Rejeição.
# 5. Calcule o Percentual de Aprovação.
# 6. Calcule o Índice de Eficiência Operacional.
# 7. Exiba um relatório contendo:
# • Produção diária;
# • Quantidade de peças rejeitadas;
# • Horas trabalhadas;
# • Taxa de Rejeição;
# • Percentual de Aprovação;
# • Índice de Eficiência Operacional.
# Todos os valores numéricos devem ser apresentados com duas casas decimais.

# %%
production = float(input("What is the daily production "))
rejected = int(input("How many pieces was rejected "))
hours_worked = float(input("How many hours of production "))

rejection_rate = (rejected / production) * 100
daily_production = (100 - rejection_rate)
efficience_index = (daily_production / 100) * daily_production
ieo = ((production - rejected) / hours_worked) * (efficience_index / 100)

print(f"{production:.2f}", f"{rejected:.2f}", f"{hours_worked:.2f}", f"{rejection_rate:.2f}", f"{efficience_index:.2f}", f"{ieo:.2f}")
# Out:
# What is the daily production 20
# How many pieces was rejected 2
# How many hours o production 10
# 20.00 2.00 10.00 10.00 81.00 1.46
